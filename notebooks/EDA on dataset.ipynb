# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mpii_dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24723 entries, 0 to 24722
# Data columns (total 37 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    24723 non-null  int64
#  1   NAME          24723 non-null  object
#  2   r ankle_X     24723 non-null  int64
#  3   r ankle_Y     24723 non-null  int64
#  4   r knee_X      24723 non-null  int64
#  5   r knee_Y      24723 non-null  int64
#  6   r hip_X       24723 non-null  int64
#  7   r hip_Y       24723 non-null  int64
#  8   l hip_X       24723 non-null  int64
#  9   l hip_Y       24723 non-null  int64
#  10  l knee_X      24723 non-null  int64
#  11  l knee_Y      24723 non-null  int64
#  12  l ankle_X     24723 non-null  int64
#  13  l ankle_Y     24723 non-null  int64
#  14  pelvis_X      24723 non-null  int64
#  15  pelvis_Y      24723 non-null  int64
#  16  thorax_X      24723 non-null  int64
#  17  thorax_Y      24723 non-null  int64
#  18  upper neck_X  24723 non-null  float64
#  19  upper neck_Y  24723 non-null  float64
#  20  head top_X    24723 non-null  float64
#  21  head top_Y    24723 non-null  float64
#  22  r wrist_X     24723 non-null  int64
#  23  r wrist_Y     24723 non-null  int64
#  24  r elbow_X     24723 non-null  int64
#  25  r elbow_Y     24723 non-null  int64
#  26  r shoulder_X  24723 non-null  int64
#  27  r shoulder_Y  24723 non-null  int64
#  28  l shoulder_X  24723 non-null  int64
#  29  l shoulder_Y  24723 non-null  int64
#  30  l elbow_X     24723 non-null  int64
#  31  l elbow_Y     24723 non-null  int64
#  32  l wrist_X     24723 non-null  int64
#  33  l wrist_Y     24723 non-null  int64
#  34  Scale         24723 non-null  float64
#  35  Activity      24723 non-null  object
#  36  Category      24723 non-null  object
# dtypes: float64(5), int64(29), object(3)
# memory usage: 7.0+ MB

# %%
df.head()
# Out:
#    Unnamed: 0           NAME  r ankle_X  r ankle_Y  r knee_X  r knee_Y  \
# 0           0  015601864.jpg        620        394       616       269
# 1           0  015599452.jpg         -1         -1        -1        -1
# 2           0  005808361.jpg        804        711       816       510
# 3           0  086617615.jpg        301        461       305       375
# 4           0  060111501.jpg        980        322       896       318
#
#    r hip_X  r hip_Y  l hip_X  l hip_Y  ...  r shoulder_Y  l shoulder_X  \
# 0      573      -71      647      -68  ...           -89           692
# 1      806      543      720      593  ...           281           719
# 2      908      438     1040      454  ...            -3          1067
# 3      -55      340      294      342  ...           261           314
# 4      865       -8      943      -30  ...          -109           923
#
#    l shoulder_Y  l elbow_X  l elbow_Y  l wrist_X  l wrist_Y     Scale  \
# 0           -71        693        -16        688        313  3.021046
# 1           299        711        516        545        466  5.641276
# 2            -3       1167        353       1142        478  4.718488
# 3           264        327        320        362        346  2.681349
# 4           123        995        -93        961        -33  3.806403
#
#    Activity  Category
# 0   curling    sports
# 1   curling    sports
# 2   curling    sports
# 3   curling    sports
# 4   curling    sports
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.describe()
# Out:
#        Unnamed: 0     r ankle_X     r ankle_Y      r knee_X      r knee_Y  \
# count     24723.0  24723.000000  24723.000000  24723.000000  24723.000000
# mean          0.0    404.584152    381.564495    477.977713    403.888646
# std           0.0    412.895984    323.776594    392.718216    278.278089
# min           0.0   -128.000000   -120.000000   -128.000000   -124.000000
# 25%           0.0     -1.000000     -1.000000     -1.000000    270.000000
# 50%           0.0    377.000000    419.000000    478.000000    439.000000
# 75%           0.0    693.000000    623.000000    741.000000    595.000000
# max           0.0   1873.000000   1108.000000   1910.000000   1152.000000
#
#             r hip_X       r hip_Y       l hip_X       l hip_Y      l knee_X  \
# count  24723.000000  24723.000000  24723.000000  24723.000000  24723.000000
# mean     573.666545    410.962262    620.897423    411.643530    519.429843
# std      367.556326    241.554953    369.504883    241.011866    405.699070
# min     -128.000000   -128.000000   -128.000000   -128.000000   -128.000000
# 25%      345.000000    310.000000    386.000000    310.000000     96.000000
# 50%      561.000000    413.000000    604.000000    414.000000    518.000000
# 75%      805.000000    555.000000    849.000000    555.000000    790.000000
# max     1888.000000   1077.000000   1908.000000   1087.000000   1916.000000
#
#        ...     r elbow_Y  r shoulder_X  r shoulder_Y  l shoulder_X  \
# count  ...  24723.000000  24723.000000  24723.000000  24723.000000
# mean   ...    308.950775    572.130041    174.970109    648.236986
# std    ...    238.691439    356.618238    226.755866    359.109243
# min    ...   -128.000000   -128.000000   -128.000000   -128.000000
# 25%    ...    115.000000    354.000000    -49.000000    414.000000
# 50%    ...    342.000000    555.000000    258.000000    626.000000
# 75%    ...    458.000000    791.000000    352.000000    867.000000
# max    ...   1059.000000   1915.000000   1033.000000   1912.000000
#
#        l shoulder_Y     l elbow_X     l elbow_Y     l wrist_X     l wrist_Y  \
# count  24723.000000  24723.000000  24723.000000  24723.000000  24723.000000
# mean     172.302512    662.201877    310.023500    649.937508    349.225296
# std      226.654176    360.463647    238.069697    353.036028    247.480952
# min     -128.000000   -128.000000   -128.000000   -128.000000   -128.000000
# 25%      -50.000000    425.000000    122.000000    417.000000    269.000000
# 50%      257.000000    637.000000    342.000000    631.000000    370.000000
# 75%      350.000000    879.000000    460.000000    861.000000    503.000000
# max      956.000000   1921.000000   1046.000000   1908.000000   1087.000000
#
#               Scale
# count  24723.000000
# mean       3.530939
# std        1.900531
# min        0.544118
# 25%        2.150111
# 50%        3.082202
# 75%        4.434808
# max       16.852803
#
# [8 rows x 34 columns]

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
plotPerColumnDistribution(df, 10, 5)
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_8456/964395601.py:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(nGraphRow, nGraphPerRow, i + 1)

# %%
plotCorrelationMatrix(df, 8)
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_8456/1054209777.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   df = df.dropna('columns') # drop columns with NaN

# %%
plotScatterMatrix(df, 20, 10)
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_8456/102845399.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   df = df.dropna('columns')

# %% [markdown]
# ## Feature Engineering

# %%
df['Category'].unique()
# Out:
# array(['sports', 'inactivity quiet/light', 'miscellaneous', 'occupation',
#        'water activities', 'home activities', 'lawn and garden',
#        'religious activities', 'winter activities',
#        'conditioning exercise', 'bicycling', 'fishing and hunting',
#        'dancing', 'walking', 'running', 'self care', 'home repair',
#        'music playing', 'transportation', 'volunteer activities', '[]'],
#       dtype=object)

# %%
indices_to_drop = df[df['Category'] == '[]'].index
df = df.drop(indices_to_drop, axis=0)

# %%
df['Category'].unique().shape, df.shape
# Out:
# ((20,), (24673, 37))

# %%
df = df.drop(['Unnamed: 0', 'NAME', 'Scale', 'Activity'], axis=1)

# %%
df.head()
# Out:
#    r ankle_X  r ankle_Y  r knee_X  r knee_Y  r hip_X  r hip_Y  l hip_X  \
# 0        620        394       616       269      573      -71      647
# 1         -1         -1        -1        -1      806      543      720
# 2        804        711       816       510      908      438     1040
# 3        301        461       305       375      -55      340      294
# 4        980        322       896       318      865       -8      943
#
#    l hip_Y  l knee_X  l knee_Y  ...  r elbow_Y  r shoulder_X  r shoulder_Y  \
# 0      -68       661       -35  ...        -95           601           -89
# 1      593        -1        -1  ...        410           647           281
# 2      454       906       528  ...        340           902            -3
# 3      342       335       370  ...        335           -12           261
# 4      -30       948       290  ...         -9           792          -109
#
#    l shoulder_X  l shoulder_Y  l elbow_X  l elbow_Y  l wrist_X  l wrist_Y  \
# 0           692           -71        693        -16        688        313
# 1           719           299        711        516        545        466
# 2          1067            -3       1167        353       1142        478
# 3           314           264        327        320        362        346
# 4           923           123        995        -93        961        -33
#
#    Category
# 0    sports
# 1    sports
# 2    sports
# 3    sports
# 4    sports
#
# [5 rows x 33 columns]

# %%
from sklearn.preprocessing import StandardScaler

X = df.drop(['Category'], axis = 1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 0.52218874,  0.03874659,  0.35203009, ..., -1.3700455 ,
#          0.10826097, -0.14678329],
#        [-0.98162201, -1.18126062, -1.21854301, ...,  0.86486736,
#         -0.2966451 ,  0.47150273],
#        [ 0.96776229,  1.01784098,  0.86112995, ...,  0.18011022,
#          1.39376693,  0.51999575],
#        ...,
#        [ 0.3817362 ,  0.72751015,  0.20439112, ...,  0.42376614,
#         -0.53449201,  0.2613663 ],
#        [ 0.22191091, -0.01376005, -0.02979482, ..., -0.07194762,
#         -0.67889907, -0.09829027],
#        [-0.10258288, -0.09715295, -0.33270924, ..., -1.54228502,
#         -1.08097362, -1.6621902 ]])

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

columns = ['feature_{}'.format(i) for i in range(X_scaled.shape[1])]
df_scaled = pd.DataFrame(X_scaled, columns=columns)

categorical_feature = df['Category']

label_encoder = LabelEncoder()
encoded_categorical = label_encoder.fit_transform(categorical_feature)

df_scaled['Category'] = encoded_categorical

# %%
df_scaled
# Out:
#        feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0       0.522189   0.038747   0.352030  -0.484144  -0.001276  -1.995383
# 1      -0.981622  -1.181261  -1.218543  -1.454055   0.632370   0.546257
# 2       0.967762   1.017841   0.861130   0.381591   0.909760   0.111612
# 3      -0.250300   0.245685  -0.439620  -0.103365  -1.709131  -0.294057
# 4       1.393963  -0.183634   1.064770  -0.308123   0.792821  -1.734596
# ...          ...        ...        ...        ...        ...        ...
# 24668   1.142117   0.245685   0.858584  -0.085403   0.558943  -0.476194
# 24669   1.534416   0.847967   1.202227   0.360037   0.896163  -0.343731
# 24670   0.381736   0.727510   0.204391   0.485766  -0.055667   0.169565
# 24671   0.221911  -0.013760  -0.029795  -0.293754  -0.172606  -0.550705
# 24672  -0.102583  -0.097153  -0.332709  -0.383561  -0.607728  -1.833943
#
#        feature_6  feature_7  feature_8  feature_9  ...  feature_23  \
# 0       0.071110  -1.990289   0.349445  -1.588950  ...   -1.692208
# 1       0.268590   0.752106  -1.281734  -1.465929  ...    0.423044
# 2       1.134253   0.175415   0.953130   0.448131  ...    0.129840
# 3      -0.883824  -0.289257  -0.453824  -0.123554  ...    0.108897
# 4       0.871849  -1.832633   1.056618  -0.413015  ...   -1.331987
# ...          ...        ...        ...        ...  ...         ...
# 24668   0.328104  -0.451063   0.460326  -0.065662  ...   -0.205249
# 24669   0.568867  -0.310001   0.719048   0.361292  ...   -0.150797
# 24670  -0.296797   0.192010   0.024195   0.477077  ...    0.351837
# 24671  -0.218346  -0.546486   0.095652  -0.264666  ...   -0.087968
# 24672  -0.821605  -1.832633  -0.547457  -0.413015  ...   -1.587492
#
#        feature_24  feature_25  feature_26  feature_27  feature_28  feature_29  \
# 0        0.081544   -1.164137    0.122345   -1.073520    0.085951   -1.370045
# 1        0.210491    0.467319    0.197505    0.558736    0.135870    0.864867
# 2        0.925304   -0.784934    1.166234   -0.773538    1.400482    0.180110
# 3       -1.636813    0.379132   -0.929895    0.404333   -0.929067    0.041478
# 4        0.616953   -1.252324    0.765380   -0.217689    0.923479   -1.693520
# ...           ...         ...         ...         ...         ...         ...
# 24668    0.370272   -0.956898    0.041617   -0.905883    0.033258   -0.101354
# 24669    0.698246   -1.000991    0.225342   -0.919118    0.116457    0.091890
# 24670    0.000251    0.890616   -0.439963    0.907245   -0.532489    0.423766
# 24671   -0.366967   -0.784934   -0.506772   -0.782361   -0.626780   -0.071948
# 24672   -0.664105   -1.159728   -1.002271   -1.108812   -1.062184   -1.542285
#
#        feature_30  feature_31  Category
# 0        0.108261   -0.146783        14
# 1       -0.296645    0.471503        14
# 2        1.393767    0.519996        14
# 3       -0.814812   -0.013427        14
# 4        0.881263   -1.544999        14
# ...           ...         ...       ...
# 24668   -0.053135   -0.360961        15
# 24669    0.071451   -0.324591        15
# 24670   -0.534492    0.261366        15
# 24671   -0.678899   -0.098290        15
# 24672   -1.080974   -1.662190        15
#
# [24673 rows x 33 columns]

# %%
df_scaled.to_csv('preprocessed_data.csv')

# %%
df1 = pd.read_csv('preprocessed_data.csv')
df1.head(5)
# Out:
#    Unnamed: 0  feature_0  feature_1  feature_2  feature_3  feature_4  \
# 0           0   0.522189   0.038747   0.352030  -0.484144  -0.001276
# 1           1  -0.981622  -1.181261  -1.218543  -1.454055   0.632370
# 2           2   0.967762   1.017841   0.861130   0.381591   0.909760
# 3           3  -0.250300   0.245685  -0.439620  -0.103365  -1.709131
# 4           4   1.393963  -0.183634   1.064770  -0.308123   0.792821
#
#    feature_5  feature_6  feature_7  feature_8  ...  feature_23  feature_24  \
# 0  -1.995383   0.071110  -1.990289   0.349445  ...   -1.692208    0.081544
# 1   0.546257   0.268590   0.752106  -1.281734  ...    0.423044    0.210491
# 2   0.111612   1.134253   0.175415   0.953130  ...    0.129840    0.925304
# 3  -0.294057  -0.883824  -0.289257  -0.453824  ...    0.108897   -1.636813
# 4  -1.734596   0.871849  -1.832633   1.056618  ...   -1.331987    0.616953
#
#    feature_25  feature_26  feature_27  feature_28  feature_29  feature_30  \
# 0   -1.164137    0.122345   -1.073520    0.085951   -1.370045    0.108261
# 1    0.467319    0.197505    0.558736    0.135870    0.864867   -0.296645
# 2   -0.784934    1.166234   -0.773538    1.400482    0.180110    1.393767
# 3    0.379132   -0.929895    0.404333   -0.929067    0.041478   -0.814812
# 4   -1.252324    0.765380   -0.217689    0.923479   -1.693520    0.881263
#
#    feature_31  Category
# 0   -0.146783        14
# 1    0.471503        14
# 2    0.519996        14
# 3   -0.013427        14
# 4   -1.544999        14
#
# [5 rows x 34 columns]
